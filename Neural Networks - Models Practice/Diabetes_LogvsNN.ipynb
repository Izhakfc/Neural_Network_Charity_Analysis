# %%
# Code to load data into colab from google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
path = "/content/gdrive/MyDrive/Neural Networks/Resources"
diabetes_df = pd.read_csv(f'{path}/diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 18/18 [==============================] - 1s 1ms/step - loss: 0.6846 - accuracy: 0.6059
# Epoch 2/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6552 - accuracy: 0.6389
# Epoch 3/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6309 - accuracy: 0.6632
# Epoch 4/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6105 - accuracy: 0.6806
# Epoch 5/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5926 - accuracy: 0.7014
# Epoch 6/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5773 - accuracy: 0.7188
# Epoch 7/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5638 - accuracy: 0.7309
# Epoch 8/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5520 - accuracy: 0.7378
# Epoch 9/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5418 - accuracy: 0.7431
# Epoch 10/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5328 - accuracy: 0.7465
# Epoch 11/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5243 - accuracy: 0.7431
# Epoch 12/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5167 - accuracy: 0.7483
# Epoch 13/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5102 - accuracy: 0.7622
# Epoch 14/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5042 - accuracy: 0.7674
# Epoch 15/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4985 - accuracy: 0.7656
# Epoch 16/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4939 - accuracy: 0.7743
# Epoch 17/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4890 - accuracy: 0.7795
# Epoch 18/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4852 - accuracy: 0.7812
# Epoch 19/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4814 - accuracy: 0.7795
# Epoch 20/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4782 - accuracy: 0.7812
# Epoch 21/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4752 - accuracy: 0.7795
# Epoch 22/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4724 - accuracy: 0.7917
# Epoch 23/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4701 - accuracy: 0.7899
# Epoch 24/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4679 - accuracy: 0.7917
# Epoch 25/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4660 - accuracy: 0.7917
# Epoch 26/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4640 - accuracy: 0.7899
# Epoch 27/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4621 - accuracy: 0.7917
# Epoch 28/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4607 - accuracy: 0.7934
# Epoch 29/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4591 - accuracy: 0.7899
# Epoch 30/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4581 - accuracy: 0.7934
# Epoch 31/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4565 - accuracy: 0.7917
# Epoch 32/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4556 - accuracy: 0.7951
# Epoch 33/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4542 - accuracy: 0.7951
# Epoch 34/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4533 - accuracy: 0.7934
# Epoch 35/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4522 - accuracy: 0.7917
# Epoch 36/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4516 - accuracy: 0.7934
# Epoch 37/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4507 - accuracy: 0.7917
# Epoch 38/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4496 - accuracy: 0.7934
# Epoch 39/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4487 - accuracy: 0.7934
# Epoch 40/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4479 - accuracy: 0.7934
# Epoch 41/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4470 - accuracy: 0.7917
# Epoch 42/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4464 - accuracy: 0.7934
# Epoch 43/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4459 - accuracy: 0.7917
# Epoch 44/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4445 - accuracy: 0.7934
# Epoch 45/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4441 - accuracy: 0.7934
# Epoch 46/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4432 - accuracy: 0.7951
# Epoch 47/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4430 - accuracy: 0.7951
# Epoch 48/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4420 - accuracy: 0.7951
# Epoch 49/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4417 - accuracy: 0.7951
# Epoch 50/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4409 - accuracy: 0.7934
# 6/6 - 0s - loss: 0.4763 - accuracy: 0.7344
# Loss: 0.4762633740901947, Accuracy: 0.734375
